# %% [markdown]
# <h1>CSV-Files</h1>
# CSV stands for "Comma Separated Values" and means that we store data in a list. List elements are separated using commas. Sometimes, other symbold are used as delimiters, such as semicolons, tabspaces, return, etc. Often, commas separate columns and return separates lines, creating a table rather than a list. Such a list or table is saved as a CSV file. CSV files usually contain strings that are saved using UTF-8, ANSI, or other character sets. CSV files have several strengths:
# <ul>
#     <li>In contrast to binary files, the raw text of CSV files (as displayed by text editors) is interpretable by readers (if not compressed)</li>
#     <li>CSV files can be imported and exported by spreadsheet softwares, like Google Docs, Microsoft Excel, <a href="https://www.openoffice.org/" target="_blank">Open Office Calc</a> and <a href="https://de.libreoffice.org/" target="_blank">Libre Office Calc</a>, by statistical softwares, such as IBM SPSS and <a href="https://cran.r-project.org/bin/windows/base/" target="_blank">R</a>, by database softwares, like <a href="https://www.mysql.com/" target="_blank">MySQL</a>, and by audio softwares, like <a href="https://www.audacity.de/" target="_blank">Audacity</a>, <a href="https://puredata.info/", target="_blank">Pure Data</a> (iemlib library) and <a href="https://sonification.highcharts.com/#/app" target="_blank">Highchart Sonification Studio</a></li>
# </ul>
# Some weaknesses of CSV files are:
# <ul>
#     <li>CSV files tend to be larger than binary files</li>
#     <li>CSV files are only semi-<a href="https://datatracker.ietf.org/doc/html/rfc4180.html" target="_blank">standardized</a> for lists and tables, but not for higher order arrays and matrices</li>
#     <li>The option to use any symbol as separator and arbitrary symbols (usually single quote or double quote) to indicate a string can cause confusion and unexpected text display</li>
#     <li>Language settings can cause awkward tables, as Germans use commas as decimal separator and, sometimes, points as thousands separator. In English it is the other way round. Language settings can even descroy existing CSV files by overwriting commas with points or the other way round.</li>
#     <li>Small errors that a human makes when manually editing a csv file can cause unexpected harm</li>
#     <li>Some softwares allow compressing CSV files when exporting them. Such a compression makes the raw text unreadable and foils the universality of CSV files.</li>
# </ul>
#
# Generally, storing data in files on a hard drive is always a good choice if you want to use it later on, in another software, or in another jupyter notebook.

# %% [markdown]
# <h2>Pandas</h2>
# Pandas is often used to import, handle, analyze and export data.

# %%
#pip install pandas
import pandas as pd

# %% [markdown]
# You can easily import a CSV file

# %%
a_list = pd.read_table(r'C:\python\gits\early-techno\example-data\germany\Captain Hollywood Project - Flying High (Spaceship Mix) (1994).mp3.csv', sep=',',index_col=0)

# %% [markdown]
# and display its content

# %%
a_list
# Out:
#         PhaseSpace  ChannelCorrelation  PeakMeter        RMS  CrestFactor  \
# 0.0         0.0650            0.997516  -1.935620 -11.557975     9.622355
# 1.0         0.0775            0.994773  -1.480405 -11.120875     9.640470
# 2.0         0.0750            0.998545  -2.611259  -7.592365     4.981106
# 3.0         0.0700            0.995732  -3.420472 -45.194821    41.774349
# 4.0         0.0150            0.995242 -18.549834 -20.813745     2.263911
# ...            ...                 ...        ...        ...          ...
# 7674.0      0.0325           -0.041810  -9.970825 -36.892638    26.921813
# 7675.0      0.0325            0.074877 -10.009109 -35.657383    25.648274
# 7676.0      0.0275            0.407785 -10.747808 -32.037168    21.289361
# 7677.0      0.0250            0.456575 -12.727383 -49.617160    36.889777
# 7678.0      0.0225            0.275594 -12.728972 -53.958184    41.229212
#
#         PhaseSpaceLow  ChannelCorrelationLow  PeakMeterLow     RMSLow  \
# 0.0            0.0625               0.997729     -4.365814 -10.215280
# 1.0            0.0800               0.995848     -1.183590  -6.533047
# 2.0            0.0725               0.998998     -2.535162  -3.866641
# 3.0            0.0725               0.997112     -2.549647 -22.412361
# 4.0            0.0150               0.992734    -18.673684 -25.383565
# ...               ...                    ...           ...        ...
# 7674.0         0.0100               0.449547    -21.360133 -33.341319
# 7675.0         0.0100               0.593814    -21.714508 -26.497132
# 7676.0         0.0100               0.736471    -21.789313 -23.177839
# 7677.0         0.0100               0.757330    -23.245507 -28.644949
# 7678.0         0.0075               0.712818    -25.783224 -55.283531
#
#         CrestFactorLow  ...  ChannelCorrelationMid  PeakMeterMid     RMSMid  \
# 0.0           5.849466  ...               0.993727    -10.731547 -14.988900
# 1.0           5.349457  ...               0.991905     -9.272907 -27.416254
# 2.0           1.331479  ...               0.989210    -13.529488 -24.457612
# 3.0          19.862714  ...               0.988271    -21.989021 -54.212844
# 4.0           6.709881  ...               0.957202    -38.817900 -46.132094
# ...                ...  ...                    ...           ...        ...
# 7674.0       11.981186  ...              -0.030037     -9.700914 -23.680416
# 7675.0        4.782623  ...              -0.041718    -10.877874 -36.747760
# 7676.0        1.388526  ...               0.279194    -12.458199 -30.875436
# 7677.0        5.399442  ...               0.432950    -12.968551 -34.124531
# 7678.0       29.500307  ...               0.237760    -13.296599 -35.434146
#
#         CrestFactorMid  PhaseSpaceHigh  ChannelCorrelationHigh  PeakMeterHigh  \
# 0.0           4.257353          0.0175                0.999906     -14.451853
# 1.0          18.143347          0.0050                0.922103     -57.206026
# 2.0          10.928124          0.0050                0.711311     -61.925656
# 3.0          32.223823          0.0050                0.605584     -68.467609
# 4.0           7.314194          0.0050                0.638600     -68.330868
# ...                ...             ...                     ...            ...
# 7674.0       13.979502          0.0100                0.240179     -24.839740
# 7675.0       25.869886          0.0050               -0.181073     -27.273891
# 7676.0       18.417237          0.0050                0.068897     -27.228361
# 7677.0       21.155979          0.0050               -0.187916     -28.510941
# 7678.0       22.137548          0.0050                0.322326     -27.350090
#
#            RMSHigh  CrestFactorHigh         bpm
# 0.0     -81.438264        66.986410  151.999081
# 1.0    -101.969236        44.763210  151.999081
# 2.0     -80.700843        18.775187  151.999081
# 3.0     -86.229192        17.761583  151.999081
# 4.0     -90.427522        22.096654  151.999081
# ...            ...              ...         ...
# 7674.0  -33.286721         8.446980  151.999081
# 7675.0  -37.422171        10.148280  151.999081
# 7676.0  -37.170043         9.941682  151.999081
# 7677.0  -35.434530         6.923589  151.999081
# 7678.0  -38.473879        11.123789  151.999081
#
# [7679 rows x 21 columns]

# %% [markdown]
# If the CSV files uses other delimiters, you can indicate them as sep <font color=#a2f>= </font><font color=#ba2121>'delimiter'</font>

# %%
#b_list = pd.read_table('composers-semicolon.csv',sep=';')#
#b_list

# %% [markdown]
# Sometimes, CSV files contain too much data to be displayed. In that case, you can use the head() function to display only the first five rows:

# %%
a_list.head()
# Out:
#      PhaseSpace  ChannelCorrelation  PeakMeter        RMS  CrestFactor  \
# 0.0      0.0650            0.997516  -1.935620 -11.557975     9.622355
# 1.0      0.0775            0.994773  -1.480405 -11.120875     9.640470
# 2.0      0.0750            0.998545  -2.611259  -7.592365     4.981106
# 3.0      0.0700            0.995732  -3.420472 -45.194821    41.774349
# 4.0      0.0150            0.995242 -18.549834 -20.813745     2.263911
#
#      PhaseSpaceLow  ChannelCorrelationLow  PeakMeterLow     RMSLow  \
# 0.0         0.0625               0.997729     -4.365814 -10.215280
# 1.0         0.0800               0.995848     -1.183590  -6.533047
# 2.0         0.0725               0.998998     -2.535162  -3.866641
# 3.0         0.0725               0.997112     -2.549647 -22.412361
# 4.0         0.0150               0.992734    -18.673684 -25.383565
#
#      CrestFactorLow  ...  ChannelCorrelationMid  PeakMeterMid     RMSMid  \
# 0.0        5.849466  ...               0.993727    -10.731547 -14.988900
# 1.0        5.349457  ...               0.991905     -9.272907 -27.416254
# 2.0        1.331479  ...               0.989210    -13.529488 -24.457612
# 3.0       19.862714  ...               0.988271    -21.989021 -54.212844
# 4.0        6.709881  ...               0.957202    -38.817900 -46.132094
#
#      CrestFactorMid  PhaseSpaceHigh  ChannelCorrelationHigh  PeakMeterHigh  \
# 0.0        4.257353          0.0175                0.999906     -14.451853
# 1.0       18.143347          0.0050                0.922103     -57.206026
# 2.0       10.928124          0.0050                0.711311     -61.925656
# 3.0       32.223823          0.0050                0.605584     -68.467609
# 4.0        7.314194          0.0050                0.638600     -68.330868
#
#         RMSHigh  CrestFactorHigh         bpm
# 0.0  -81.438264        66.986410  151.999081
# 1.0 -101.969236        44.763210  151.999081
# 2.0  -80.700843        18.775187  151.999081
# 3.0  -86.229192        17.761583  151.999081
# 4.0  -90.427522        22.096654  151.999081
#
# [5 rows x 21 columns]

# %% [markdown]
# Sometimes, you need a quick check of the type of data and the consistency of a CSV table. You can do that via info(). It tells you,
# <ul>
#     <li>whether your data is of the Series or DataFrame class</li>
#     <li>how many rows you've got</li>
#     <li>how many columns you've got</li>
#     <li>the names of all columns</li>
#     <li>the data types contained in all columns</li>
#     <li>the memory occupied by the table</li>
#     <li>the table's data type (Series or DataFrame)</li>
# </ul>

# %%
a_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 7679 entries, 0.0 to 7678.0
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   PhaseSpace              7679 non-null   float64
#  1   ChannelCorrelation      7679 non-null   float64
#  2   PeakMeter               7679 non-null   float64
#  3   RMS                     7679 non-null   float64
#  4   CrestFactor             7679 non-null   float64
#  5   PhaseSpaceLow           7679 non-null   float64
#  6   ChannelCorrelationLow   7679 non-null   float64
#  7   PeakMeterLow            7679 non-null   float64
#  8   RMSLow                  7679 non-null   float64
#  9   CrestFactorLow          7679 non-null   float64
#  10  PhaseSpaceMid           7679 non-null   float64
#  11  ChannelCorrelationMid   7679 non-null   float64
#  12  PeakMeterMid            7679 non-null   float64
#  13  RMSMid                  7679 non-null   float64
#  14  CrestFactorMid          7679 non-null   float64
#  15  PhaseSpaceHigh          7679 non-null   float64
#  16  ChannelCorrelationHigh  7679 non-null   float64
#  17  PeakMeterHigh           7679 non-null   float64
#  18  RMSHigh                 7679 non-null   float64
#  19  CrestFactorHigh         7679 non-null   float64
#  20  bpm                     7679 non-null   float64
# dtypes: float64(21)
# memory usage: 1.3 MB

# %% [markdown]
# To display all column names, you can loop through the DataFrame or via list() command:

# %%
for col in a_list.columns:
    print(col)
list(a_list.columns)
# Out:
# PhaseSpace
# ChannelCorrelation
# PeakMeter
# RMS
# CrestFactor
# PhaseSpaceLow
# ChannelCorrelationLow
# PeakMeterLow
# RMSLow
# CrestFactorLow
# PhaseSpaceMid
# ChannelCorrelationMid
# PeakMeterMid
# RMSMid
# CrestFactorMid
# PhaseSpaceHigh
# ChannelCorrelationHigh
# PeakMeterHigh
# RMSHigh
# CrestFactorHigh
# bpm
# ['PhaseSpace',
#  'ChannelCorrelation',
#  'PeakMeter',
#  'RMS',
#  'CrestFactor',
#  'PhaseSpaceLow',
#  'ChannelCorrelationLow',
#  'PeakMeterLow',
#  'RMSLow',
#  'CrestFactorLow',
#  'PhaseSpaceMid',
#  'ChannelCorrelationMid',
#  'PeakMeterMid',
#  'RMSMid',
#  'CrestFactorMid',
#  'PhaseSpaceHigh',
#  'ChannelCorrelationHigh',
#  'PeakMeterHigh',
#  'RMSHigh',
#  'CrestFactorHigh',
#  'bpm']

# %% [markdown]
# You can display column names using the keys() command:

# %%
print(a_list.keys())
# Out:
# Index(['PhaseSpace', 'ChannelCorrelation', 'PeakMeter', 'RMS', 'CrestFactor',
#        'PhaseSpaceLow', 'ChannelCorrelationLow', 'PeakMeterLow', 'RMSLow',
#        'CrestFactorLow', 'PhaseSpaceMid', 'ChannelCorrelationMid',
#        'PeakMeterMid', 'RMSMid', 'CrestFactorMid', 'PhaseSpaceHigh',
#        'ChannelCorrelationHigh', 'PeakMeterHigh', 'RMSHigh', 'CrestFactorHigh',
#        'bpm'],
#       dtype='object')

# %% [markdown]
# You can quickly calculate statistics like mean:

# %%
a_list.mean()
# Out:
# PhaseSpace                  0.069116
# ChannelCorrelation          0.815819
# PeakMeter                  -3.227079
# RMS                       -16.690830
# CrestFactor                13.463750
# PhaseSpaceLow               0.039585
# ChannelCorrelationLow       0.881746
# PeakMeterLow              -10.672712
# RMSLow                    -21.530061
# CrestFactorLow             10.857348
# PhaseSpaceMid               0.038590
# ChannelCorrelationMid       0.685153
# PeakMeterMid               -9.840876
# RMSMid                    -25.053595
# CrestFactorMid             15.212719
# PhaseSpaceHigh              0.026268
# ChannelCorrelationHigh      0.755081
# PeakMeterHigh             -15.285736
# RMSHigh                   -33.783105
# CrestFactorHigh            18.497369
# bpm                       151.999081
# dtype: float64

# %%
a_list.std()# standard deviation
# Out:
# PhaseSpace                1.525595e-02
# ChannelCorrelation        2.737943e-01
# PeakMeter                 2.389379e+00
# RMS                       9.873347e+00
# CrestFactor               9.403868e+00
# PhaseSpaceLow             2.238997e-02
# ChannelCorrelationLow     3.196356e-01
# PeakMeterLow              8.411034e+00
# RMSLow                    1.292388e+01
# CrestFactorLow            9.360614e+00
# PhaseSpaceMid             1.923020e-02
# ChannelCorrelationMid     3.109339e-01
# PeakMeterMid              5.993462e+00
# RMSMid                    1.150186e+01
# CrestFactorMid            1.029301e+01
# PhaseSpaceHigh            1.106454e-02
# ChannelCorrelationHigh    2.561669e-01
# PeakMeterHigh             1.240896e+01
# RMSHigh                   1.667729e+01
# CrestFactorHigh           1.054504e+01
# bpm                       2.842356e-14
# dtype: float64

# %%
a_list.var()# variance
# Out:
# PhaseSpace                2.327440e-04
# ChannelCorrelation        7.496334e-02
# PeakMeter                 5.709133e+00
# RMS                       9.748298e+01
# CrestFactor               8.843274e+01
# PhaseSpaceLow             5.013105e-04
# ChannelCorrelationLow     1.021669e-01
# PeakMeterLow              7.074549e+01
# RMSLow                    1.670267e+02
# CrestFactorLow            8.762110e+01
# PhaseSpaceMid             3.698004e-04
# ChannelCorrelationMid     9.667987e-02
# PeakMeterMid              3.592158e+01
# RMSMid                    1.322928e+02
# CrestFactorMid            1.059461e+02
# PhaseSpaceHigh            1.224239e-04
# ChannelCorrelationHigh    6.562146e-02
# PeakMeterHigh             1.539822e+02
# RMSHigh                   2.781321e+02
# CrestFactorHigh           1.111979e+02
# bpm                       8.078988e-28
# dtype: float64

# %%
a_list.min()# lowest value
# Out:
# PhaseSpace                  0.012500
# ChannelCorrelation         -0.586098
# PeakMeter                 -18.896247
# RMS                       -78.917217
# CrestFactor                 0.000000
# PhaseSpaceLow               0.005000
# ChannelCorrelationLow      -0.941066
# PeakMeterLow              -45.183068
# RMSLow                    -85.416365
# CrestFactorLow              0.000000
# PhaseSpaceMid               0.005000
# ChannelCorrelationMid      -0.884904
# PeakMeterMid              -39.196883
# RMSMid                   -106.853104
# CrestFactorMid              0.000000
# PhaseSpaceHigh              0.005000
# ChannelCorrelationHigh     -0.403535
# PeakMeterHigh             -73.131897
# RMSHigh                  -128.771698
# CrestFactorHigh             0.000000
# bpm                       151.999081
# dtype: float64

# %%
a_list.max()# highest value
# Out:
# PhaseSpace                  0.100000
# ChannelCorrelation          0.999962
# PeakMeter                   0.000000
# RMS                        -0.928246
# CrestFactor                75.180477
# PhaseSpaceLow               0.102500
# ChannelCorrelationLow       0.999999
# PeakMeterLow                0.400228
# RMSLow                     -0.288642
# CrestFactorLow             75.405465
# PhaseSpaceMid               0.110000
# ChannelCorrelationMid       0.999996
# PeakMeterMid                1.539704
# RMSMid                     -0.896232
# CrestFactorMid             98.806342
# PhaseSpaceHigh              0.067500
# ChannelCorrelationHigh      1.000000
# PeakMeterHigh              -1.909766
# RMSHigh                    -5.582387
# CrestFactorHigh           109.191002
# bpm                       151.999081
# dtype: float64

# %%
a_list.boxplot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# You can convert DataFrames to numpy arrays using

# %% [markdown]
# The sklearn library, which contains a large number of standard machine learning functions, accepts either DataFrames or numpy arrays. The following example is a random forest classifier that reads one CSV file that contains a five-dimensional feature vector (f1 to f5) and the respective class for each item (line) of a dataset:

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
drumtypes = pd.read_csv('mfccs.csv')
y = drumtypes['class']#these are the class labels that need to be predicted by the clasifier
X = drumtypes.drop(['class'], axis = 1)#
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=9)
rf = RandomForestClassifier()#load an instance of the RF classifier
rf.fit(X_train, y_train)
print(f'Train Accuracy: {rf.score(X_train, y_train):.3f}')
print(f'Test Accuracy: {rf.score(X_test, y_test):.3f}')
# Out:
# Train Accuracy: 1.000
# Test Accuracy: 0.906
